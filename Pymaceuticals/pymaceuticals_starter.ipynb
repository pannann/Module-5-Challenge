# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="right")
desired_columns = ['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)']
combined_data = combined_data[desired_columns]
combined_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
num_unique_mice = combined_data["Mouse ID"].nunique()
print(f"Number of unique mice: {num_unique_mice}")
# Out:
# Number of unique mice: 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = combined_data[combined_data.duplicated(subset=['Mouse ID', 'Timepoint'])]['Mouse ID'].unique()
import numpy as np
output_array = np.array(duplicate_mice, dtype=object)
output_array
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_id = duplicate_mice[0]
duplicate_data = combined_data.loc[combined_data['Mouse ID'] == duplicate_mouse_id]
columns_to_print = ['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)']
duplicate_data[columns_to_print]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_data = combined_data.drop_duplicates(subset=['Mouse ID'], keep='first')
cleaned_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
unique_mice = cleaned_data['Mouse ID'].unique()
num_unique_mice = len(unique_mice)
num_unique_mice
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

grouped_data = combined_data.groupby('Drug Regimen')

mean_tumor_volume = grouped_data['Tumor Volume (mm3)'].mean()

median_tumor_volume = grouped_data['Tumor Volume (mm3)'].median()

variance_tumor_volume = grouped_data['Tumor Volume (mm3)'].var()

std_deviation_tumor_volume = grouped_data['Tumor Volume (mm3)'].std()

sem_tumor_volume = grouped_data['Tumor Volume (mm3)'].apply(st.sem)

# Create a summary DataFrame to store the results
summary_statistics = pd.DataFrame({
    'Mean Tumor Volume': mean_tumor_volume,
    'Median Tumor Volume': median_tumor_volume,
    'Tumor Volume Variance': variance_tumor_volume,
    'Tumor Volume Std. Deviation': std_deviation_tumor_volume,
    'Tumor Volume SEM': sem_tumor_volume
})

summary_statistics
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Deviation  Tumor Volume SEM
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
grouped_data = combined_data.groupby('Drug Regimen')['Tumor Volume (mm3)']

summary_statistics = grouped_data.agg([
    ('Mean Tumor Volume', np.mean),
    ('Median Tumor Volume', np.median),
    ('Tumor Volume Variance', np.var),
    ('Tumor Volume Std. Deviation', np.std),
])

summary_statistics['Tumor Volume SEM'] = grouped_data.apply(st.sem)

# Display the summary statistics table
summary_statistics
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Deviation  Tumor Volume SEM
# Drug Regimen
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
drug_regimen_counts = combined_data['Drug Regimen'].value_counts()
drug_regimen_counts.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Drug Regimen')
plt.ylabel('# of observed mouse Timepoints')
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
drug_regimen_counts = combined_data['Drug Regimen'].value_counts()
drug_regimens = drug_regimen_counts.index
counts = drug_regimen_counts.values
plt.figure(figsize=(10, 6))
plt.bar(drug_regimens, counts)
plt.xlabel('Drug Regimen')
plt.ylabel('# of observed mouse Timepoints')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex_counts = combined_data['Sex'].value_counts()
sex_counts.plot(kind='pie', autopct=lambda p: f'{round(p)}%', colors=['blue', 'coral'], figsize=(4, 4))
plt.axis('equal')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex_counts = combined_data['Sex'].value_counts()
plt.figure(figsize=(4, 4))
rounded_percentages = [round((count / sex_counts.sum()) * 100) for count in sex_counts]
labels = [f'{sex} ({percentage}%)' for sex, percentage in zip(sex_counts.index, rounded_percentages)]
colors = ['blue', 'coral']
plt.pie(sex_counts, labels=labels, autopct='%1.0f%%', colors=colors, textprops={'fontsize': 12})
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
treatment_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
filtered_data = combined_data[combined_data['Drug Regimen'].isin(treatment_regimens)]
last_timepoints = filtered_data.groupby('Mouse ID')['Timepoint'].max()
final_tumor_volume_data = pd.merge(
    last_timepoints.reset_index(),
    filtered_data,
    on=['Mouse ID', 'Timepoint'],
    how='left'
)
final_tumor_volume_data[['Mouse ID', 'Drug Regimen', 'Timepoint', 'Tumor Volume (mm3)']].head()
# Out:
#   Mouse ID Drug Regimen  Timepoint  Tumor Volume (mm3)
# 0     a203    Infubinol         45           67.973419
# 1     a251    Infubinol         45           65.525743
# 2     a275     Ceftamin         45           62.999356
# 3     a411     Ramicane         45           38.407618
# 4     a444     Ramicane         45           43.047543

# %%
# Put treatments into a list for for loop (and later for plot labels)

tumor_volume_data = []

for regimen in treatment_regimens:
    
    regimen_data = final_tumor_volume_data[final_tumor_volume_data['Drug Regimen'] == regimen]
    
    tumor_volume = regimen_data['Tumor Volume (mm3)']
    
    quartiles = tumor_volume.quantile([0.25, 0.5, 0.75])
    lower_quartile = quartiles[0.25]
    upper_quartile = quartiles[0.75]
    iqr = upper_quartile - lower_quartile
    
    lower_bound = lower_quartile - 1.5 * iqr
    upper_bound = upper_quartile + 1.5 * iqr
    
    potential_outliers = regimen_data[(regimen_data['Tumor Volume (mm3)'] < lower_bound) | (regimen_data['Tumor Volume (mm3)'] > upper_bound)]
    
    print(f"{regimen}'s potential outliers: {potential_outliers['Tumor Volume (mm3)'].dropna()}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 15    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
data_to_plot = []

for regimen in treatment_regimens:
    regimen_data = final_tumor_volume_data[final_tumor_volume_data['Drug Regimen'] == regimen]['Tumor Volume (mm3)']
    data_to_plot.append(regimen_data)

plt.figure(figsize=(8, 6))
box = plt.boxplot(data_to_plot,flierprops = dict(marker = "o", markerfacecolor = "red"), labels=treatment_regimens, vert= True, patch_artist=True, medianprops={'color': 'orange'})


plt.ylabel('Final Tumor Volume (mm3)')
plt.grid(axis='y')
for patch in box['boxes']:
    patch.set_facecolor('white')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
mouse_id = 'l509'

mouse_data = combined_data[(combined_data['Mouse ID'] == mouse_id) & (combined_data['Drug Regimen'] == 'Capomulin')]

plt.figure(figsize=(10, 6))
plt.plot(mouse_data['Timepoint'], mouse_data['Tumor Volume (mm3)'], marker='o', color='b')

plt.xlabel('Time Point (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title(f'Capomulin Treatmentt for Mouse {mouse_id}')

plt.grid(True)
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
capomulin_data = combined_data[combined_data['Drug Regimen'] == 'Capomulin']

average_tumor_volume = capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

mouse_weight = capomulin_data.groupby('Mouse ID')['Weight (g)'].unique().apply(lambda x: x[0])

plt.figure(figsize=(10, 6))
plt.scatter(mouse_weight, average_tumor_volume, marker='o', color='blue', edgecolors='black', alpha=0.75)

plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Mouse Weight vs. Average Tumor Volume (Capomulin Regimen)')

plt.grid(True)
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
from scipy.stats import linregress
capomulin_data = combined_data[combined_data['Drug Regimen'] == 'Capomulin']

average_tumor_volume = capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

mouse_weight = capomulin_data.groupby('Mouse ID')['Weight (g)'].unique().apply(lambda x: x[0])

correlation_coefficient = np.corrcoef(mouse_weight, average_tumor_volume)[0, 1]

plt.figure(figsize=(10, 6))
plt.scatter(mouse_weight, average_tumor_volume, marker='o', color='blue', edgecolors='black', alpha=0.75)

plt.xlabel('Mouse Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Mouse Weight vs. Average Tumor Volume (Capomulin Regimen)')

slope, intercept, r_value, p_value, std_err = linregress(mouse_weight, average_tumor_volume)
regression_line = slope * mouse_weight + intercept

plt.plot(mouse_weight, regression_line, color='red', linestyle='--', label='Linear Regression')

plt.annotate(f'Correlation Coefficient = {correlation_coefficient:.2f}', xy=(20, 35), fontsize=12, color='green')

plt.grid(True)
plt.legend()
plt.show()

print(f'Correlation Coefficient: {correlation_coefficient:.2f}')
# Out:
# Correlation Coefficient: 0.84
